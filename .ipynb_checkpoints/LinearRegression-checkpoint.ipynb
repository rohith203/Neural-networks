# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class LinearRegression:
    def init_weights(self, s):
        np.random.seed(11)
        self.W = np.random.randn(s[1],1)
        self.cost_arr = []
        self.cost = 0
        self.gradient = 0
        
    def get_cost(self, X, y):
        total_cost = 0
        for i in range(X.shape[0]):
            total_cost += np.square(self.get_h_i(X, i)-y[i])
        return 0.5*total_cost
    
    def add_bias(self, X):
        bias = np.ones((X.shape[0],1))
        return np.concatenate((bias,X), axis=1)
    
    def get_h_i(self, X, i):
        h_i = 0
        for j in range(X.shape[1]):
            h_i += X[i][j]*self.W[j][0]
        return h_i
    
    def batch_gradient_descent(self, X, y, alpha):
        W_new = self.W.copy()
        for j in range(X.shape[1]):
            temp = 0
            for i in range(X.shape[0]):
                temp += (self.get_h_i(X, i) - y[i])*X[i][j]
            W_new[j][0] = self.W[j][0] - alpha*temp
        return W_new
        
    def train(self, X, y, alpha, num_iter=100):
        X = self.add_bias(X)
        self.init_weights(X.shape)
        for iteration in range(num_iter):
            self.W = self.batch_gradient_descent(X,y,alpha)
            self.cost_arr.append(self.get_cost(X, y))
        return self.cost_arr
        
    def test(self,X):
        X = self.add_bias(X)
        y_pred = np.ones(X.shape[0])
        for i in range(X.shape[0]):
            for j in range(X.shape[1]):
                y_pred[i] += X[i][j]*self.W[j][0]
        return y_pred

# %%
model = LinearRegression()

# %%
plt.plot(X,y + np.random.randn(X.shape[0],))

# %%
X = np.linspace(0,10,500).reshape(-1,1).astype(float)
y = 2*X.reshape(-1,) + np.random.randn(X.shape[0],)

# %%
arr = model.train(X,y,0.0001,350)

# %%
arr
# Out:
# [17256.124502981467,
#  8725.32782284703,
#  4469.36773380964,
#  2344.674425441887,
#  1282.582279181264,
#  750.312744825193,
#  482.250591792573,
#  345.9732980659055,
#  275.46080614673525,
#  237.79764728789857,
#  216.57248468074926,
#  203.60205454206385,
#  194.8051857708172,
#  188.14581635807224,
#  182.60749571602594,
#  177.68212813435093,
#  173.115088080739,
#  168.77814816373336,
#  164.60612734979557,
#  160.5653065492593,
#  156.63768165174065,
#  152.8131122449518,
#  149.08540669672695,
#  145.45036970455988,
#  141.90482823836825,
#  138.44614527177689,
#  135.07197671347302,
#  131.78014960015042,
#  128.5686007589636,
#  125.43534563158836,
#  122.37846214970756,
#  119.39608212847867,
#  116.48638642187787,
#  113.64760196700708,
#  110.87799978330153,
#  108.17589346064591,
#  105.53963790377031,
#  102.96762821664093,
#  100.45829866857885,
#  98.01012171276493,
#  95.62160704221931,
#  93.29130067554452,
#  91.01778406831829,
#  88.79967324782208,
#  86.6356179696928,
#  84.52430089554485,
#  82.46443679084355,
#  80.45477174242586,
#  78.49408239514615,
#  76.58117520714934,
#  74.7148857233054,
#  72.89407786635655,
#  71.11764324534367,
#  69.38450048088798,
#  67.69359454691417,
#  66.04389612841948,
#  64.4344009948916,
#  62.864129388997895,
#  61.33212543017151,
#  59.837456532733675,
#  58.37921283819374,
#  56.95650666138752,
#  55.56847195011015,
#  54.21426375791987,
#  52.89305772978848,
#  51.60404960028683,
#  50.34645470400033,
#  49.11950749787394,
#  47.92246109519987,
#  46.75458681095996,
#  45.61517371824937,
#  44.50352821550998,
#  43.418973604310295,
#  42.36084967741446,
#  41.328512316891086,
#  1.1838742870348309,
#  1.1550231741328083,
#  1.1268751652045537,
#  1.0994131255489445,
#  1.0726203380388557,
#  1.0464804929449212,
#  1.0209776780072495,
#  0.9960963687489661,
#  0.9718214190259951,
#  0.9481380518070442,
#  0.9250318501782172,
#  0.9024887485670561,
#  0.880495024180205,
#  0.8590372886499115,
#  0.8381024798840606,
#  0.8176778541147316,
#  0.797750978140735,
#  0.7783097217589479,
#  0.7593422503803304,
#  0.7408370178257232,
#  0.7227827592972905,
#  0.7051684845212405,
#  0.687983471057657,
#  0.6712172577733573,
#  0.6548596384738388,
#  0.6389006556903609,
#  0.6233305946185294,
#  0.6081399772045242,
#  0.593319556375454,
#  0.5788603104103635,
#  0.564753437448391,
#  0.5509903501306919,
#  0.537562670373103,
#  0.5244622242660265,
#  0.5116810370987233,
#  0.4992113285048003,
#  0.4870455077260294,
#  0.47517616899157405,
#  0.4635960870098264,
#  0.4522982125701758,
#  0.44127566825177417,
#  0.4305217442371505,
#  0.42002989422756004,
#  0.40979373145817083,
#  0.3998070248100747,
#  0.39006369501725496,
#  0.3805578109659025,
#  0.37128358608394285,
#  0.3622353748185333,
#  0.35340766919940947,
#  0.3447950954859866,
#  0.3363924108961762,
#  0.32819450041493553,
#  0.32019637368053844,
#  0.3123931619467906,
#  0.3047801151192203,
#  0.2973525988635739,
#  0.2901060917846649,
#  0.28303618267412645,
#  0.27613856782504753,
#  0.2694090484122366,
#  0.2628435279362138,
#  0.25643800972950426,
#  0.250188594523765,
#  0.24409147807613557,
#  0.23814294885346124,
#  0.23233938577295693,
#  0.22667725599791633,
#  0.2211531127871587,
#  0.21576359339684936,
#  0.21050541703351972,
#  0.20537538285688567,
#  0.20037036803141792,
#  0.19548732582532827,
#  0.19072328375593586,
#  0.18607534178021187,
#  0.18154067052940837,
#  0.17711650958671993,
#  0.17280016580692872,
#  0.1685890116769764,
#  0.1644804837165314,
#  0.16047208091747278,
#  0.1565613632214477,
#  0.15274595003453467,
#  0.14902351877808026,
#  0.14539180347485317,
#  0.14184859336966996,
#  0.13839173158365073,
#  0.13501911380121023,
#  0.13172868698911103,
#  0.12851844814671218,
#  0.12538644308664565,
#  0.12233076524526618,
#  0.11934955452201633,
#  0.11644099614717192,
#  0.11360331957706815,
#  0.11083479741634365,
#  0.1081337443664116,
#  0.10549851619953793,
#  0.10292750875795005,
#  0.10041915697733944,
#  0.09797193393414427,
#  0.09558434991604162,
#  0.09325495151513526,
#  0.09098232074318245,
#  0.08876507416844552,
#  0.08660186207351056,
#  0.0844913676337138,
#  0.08243230611549043,
#  0.08042342409434966,
#  0.07846349869186144,
#  0.07655133683123083,
#  0.07468577451105604,
#  0.07286567609672724,
#  0.07108993362915761,
#  0.06935746615031017,
#  0.0676672190451796,
#  0.06601816339981006,
#  0.06440929537497758,
#  0.06283963559508829,
#  0.06130822855202009,
#  0.05981414202344893,
#  0.05835646650540079,
#  0.056934314658578046,
#  0.05554682076821947,
#  0.05419314021709826,
#  0.05287244897138091,
#  0.05158394307899952,
#  0.05032683818027884,
#  0.04910036903043321,
#  0.047903789033771016,
#  0.04673636978919065]

# %%
model.W
# Out:
# array([[0.0273024 ],
#        [1.99587845]])
